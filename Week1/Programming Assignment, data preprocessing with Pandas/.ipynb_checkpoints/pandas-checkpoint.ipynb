# %% [markdown]
# # Programming Assignment: Предобработка данных в Pandas

# %%
import pandas as pd
data = pd.read_csv('titanic.csv', index_col='PassengerId')

# %%
data[:10]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# #### 1. Какое количество мужчин и женщин ехало на корабле? В качестве ответа приведите два числа через пробел.
# 577 314

# %%
data['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# #### 2. Какой части пассажиров удалось выжить? Посчитайте долю выживших пассажиров. Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.
# 38.38

# %%
from __future__ import division
survived = data['Survived'].value_counts()[1]
all_passengers = len(data.index)
survived_part = (survived / all_passengers) * 100
print("%.2f" % survived_part)
# Out:
# 38.38

# %% [markdown]
# #### 3. Какую долю пассажиры первого класса составляли среди всех пассажиров? Ответ приведите в процентах (число в интервале от 0 до 100, знак процента не нужен), округлив до двух знаков.
# 24.24

# %%
print("%.2f" % ((data['Pclass'].value_counts()[1] / all_passengers) * 100))
# Out:
# 24.24

# %% [markdown]
# #### 4. Какого возраста были пассажиры? Посчитайте среднее и медиану возраста пассажиров. В качестве ответа приведите два числа через пробел.
# 29.70 28.0

# %%
print("%.2f" % data['Age'].mean())
# Out:
# 29.70

# %%
data['Age'].median()
# Out:
# 28.0

# %% [markdown]
# #### 5. Коррелируют ли число братьев/сестер/супругов с числом родителей/детей? Посчитайте корреляцию Пирсона между признаками SibSp и Parch.
# 0.41

# %%
print("%.2f" % data['SibSp'].corr(data['Parch']))
# Out:
# 0.41

# %% [markdown]
# #### 6. Какое самое популярное женское имя на корабле? Извлеките из полного имени пассажира (колонка Name) его личное имя (First Name). Это задание — типичный пример того, с чем сталкивается специалист по анализу данных. Данные очень разнородные и шумные, но из них требуется извлечь необходимую информацию. Попробуйте вручную разобрать несколько значений столбца Name и выработать правило для извлечения имен, а также разделения их на женские и мужские.
# William

# %%
data['Name']
# Out:
# PassengerId
# 1                                Braund, Mr. Owen Harris
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                 Heikkinen, Miss. Laina
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                               Allen, Mr. William Henry
# 6                                       Moran, Mr. James
# 7                                McCarthy, Mr. Timothy J
# 8                         Palsson, Master. Gosta Leonard
# 9      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                   Nasser, Mrs. Nicholas (Adele Achem)
# 11                       Sandstrom, Miss. Marguerite Rut
# 12                              Bonnell, Miss. Elizabeth
# 13                        Saundercock, Mr. William Henry
# 14                           Andersson, Mr. Anders Johan
# 15                  Vestrom, Miss. Hulda Amanda Adolfina
# 16                      Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
import string
import numpy as np

def substrings_in_string(big_string, substrings):
    for substring in substrings:
        if string.find(big_string, substring) != -1:
            return substring
    print big_string
    return np.nan

title_list=['Mrs', 'Mr', 'Master', 'Miss', 'Major', 'Rev', 
                    'Dr', 'Ms', 'Mlle','Col', 'Capt', 'Mme', 'Countess',
                    'Don', 'Jonkheer']

data['Title'] = data['Name'].map(lambda x: substrings_in_string(x, title_list))

#replacing all titles with mr, mrs, miss, master
def replace_titles(x):
    title=x['Title']
    if title in ['Don', 'Major', 'Capt', 'Jonkheer', 'Rev', 'Col']:
        return 'Mr'
    elif title in ['Countess', 'Mme']:
        return 'Mrs'
    elif title in ['Mlle', 'Ms']:
        return 'Miss'
    elif title =='Dr':
        if x['Sex']=='Male':
            return 'Mr'
        else:
            return 'Mrs'
    else:
        return title

data['Title']=data.apply(replace_titles, axis=1)
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked Title
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S    Mr
# 2                1      0          PC 17599  71.2833   C85        C   Mrs
# ...

# %%
n = data['Name'].str.replace('\(|\)|\"', '', case=False)
n.str.extract(r'(Mrs|Miss|Ms). (.*) (.*)', expand=False)[1]
# Out:
# PassengerId
# 1                                  NaN
# 2         John Bradley Florence Briggs
# 3                                  NaN
# 4               Jacques Heath Lily May
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9         Oscar W Elisabeth Vilhelmina
# 10                      Nicholas Adele
# 11                          Marguerite
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                        Hulda Amanda
# 16                     Mary D Kingcome
# 17                                 NaN
# 18                                 NaN
# 19                 Julius Emelia Maria
# 20                                 NaN
# 21                                 NaN
# 22                                 NaN
# 23                                Anna
# 24                                 NaN
# ...

# %%
names = data['Name'].str.replace('\(|\)|\"', '', case=False)
names_woman = names.str.extract(r'(Mrs|Miss). (\w*) (\w*)', expand=False)
#names_woman = names.str.extract(r'(Mrs|Miss). (.*)', expand=False)
names_woman_df = names_woman.dropna()
names_woman = names_woman_df[1].str.split(" ")

names_list = names_woman.values.tolist()

#flatten = lambda l: [item for sublist in names_list for item in sublist]
flat_list = [item for sublist in names_list for item in sublist]

from collections import Counter
count = Counter(flat_list)
freq = count.values()
flat_list[max(freq)]
#total = freq.count()
# Out:
# 'Mary'
